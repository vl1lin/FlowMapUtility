# %% [markdown]
# # Задачи
# Здесь собраны задачи, идеи, которые можно добавить в утилиту

# %% [markdown]
# ## Более глобальные
# ### Добавить корреляции для горизонтальной трубы и наклонной трубы
# - В блоке **Correlation** нужно создать файлы с коддомдля других корреляций
# - Добавить имена корреляций в словарь в классе фабрики
# - Сделать выбор имени корреляции необязательным (добавить возможность выбора корреляции исходя из угла наклона трубы)
#
# ### Залоггировать всю утилиту

# %% [markdown]
# ## Точечные изменения
# ### Добавить проверку и перевод в СИ параметров потока
# - В файле **Data_Block_1.adapter_for_data.py** в классе FluidApdapter добавить перевод из:
# - г/м³ -> кг/м³
# - cПЗ -> Па·с
# - мПа -> Н/м
# **ВЫПОЛНЕНО** и **ПРОТЕСТИРОВАНО**
